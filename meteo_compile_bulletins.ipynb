# %% [markdown]
# Extract VRXA0 bulletins and save data to parquet files.
# Retrieve the same data from the MeteoSwiss DWH (NB: This is accessible only internally) and save data to parquet files.
# Provide plotting functions for data visualization.
#
# joerg.klausen@meteoswiss.ch

# %%
import os
import polars as pl

from processing.meteo import Meteo

met = Meteo()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-48z0b6_7 because the default path (/prod/zue/fc_development/users/atr/cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# Unarchive files
from housekeeping import organize_files
instr = "meteo"
source = f"/product_data/data/pay/Kenya/MKN/incoming/{instr}"
archive = f"/product_data/data/pay/Kenya/MKN/archive/{instr}"
n = organize_files.move_files(source=os.path.join(archive, "2022"), target=source, pattern="VRXA00.\d{12}")

# %%
# Extract and collate VRXA0 bulletins
source = "/product_data/data/pay/Kenya/MKN/incoming/meteo"
target = "/home/zue/users/jkl/Public/git/gawkenya/data/level1"
archive = "/product_data/data/pay/Kenya/MKN/archive/meteo"
issues = "/product_data/data/pay/Kenya/MKN/incoming_with_issues/meteo"

years = ["2022"]
for year in years:
    if os.path.exists(source):
        met.compile_vrxa00_to_parquet(source=source, target=target, base=year, archive=archive, issues=issues)
# Out:
# Processing source /product_data/data/pay/Kenya/MKN/incoming/meteo/2022 ...
# at least one key is required in a group_by operation

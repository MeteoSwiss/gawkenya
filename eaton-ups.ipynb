# %%
import polars as pl

source = 'data/ups/ups-logMeasures-20250125.csv'
# source = 'data/ups/ups-logMeasures-20240325.csv'
df = pl.read_csv(source=source, skip_rows=1, try_parse_dates=True)
df.describe()

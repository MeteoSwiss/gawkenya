# %%
from processing.cams import download_cams_monthly_ozone_data, convert_cams_nc_to_parquet
from toolbox.total_column_ozone import total_column_ozone_from_pressure_profile

# %%
# retrieve all CAMS data for NRB
download_cams_monthly_ozone_data()

# %%
# batch convert all .nc files
# for year in range(2003, 2024):
#     filepath = f'data/level3/copernicus/cams/eac4/cams-global-reanalysis-eac4-monthly_{year}'
#     convert_cams_nc_to_parquet(filepath)

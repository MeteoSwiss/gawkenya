# %% [markdown]
# Run this script at MeteoSwiss to organize and assess the files available on our netshares.
#
# Author: joerg.klausen@meteoswiss.ch
#
# [TODO] add newly added files to the level1 .parquet files upon execution

# %%
import yaml
import housekeeping.organize_files as hk
import monitoring.file_coverage as fc

with open("mch-config.yml", "r") as fh:
    cfg = yaml.safe_load(fh)
    fh.close()

# %%
# organize newly incoming files on disk
mkn = cfg["mkn"]
n = hk.organize_files(mkn, branch="incoming", verbosity=1)
# m = n = hk.organize_files(mkn, branch="archive", verbosity=1)
# Out:
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/aerosol'. 0 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/ae33/data'. 2 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/meteo'. 2 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/tei49c'. 2 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/tei49i'. 2 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/g2401'. 0 files moved.

# %%
# show and plot file statistics
days = 7
stats = fc.get_file_coverage(cfg=mkn, days=days)
display(df:=fc.print_coverage(stats=stats, days=days))
fc.plot_coverage(stats=stats, days=days)
# Out:
#         index  aerosol  ae33/data  meteo  tei49c  tei49i  g2401
# 0    expected       24        144    144     144     144     24
# 1  2024-04-08       24        144    144     144     144     23
# 2  2024-04-09       18        111    112     111     111     19
# 3  2024-04-10       24        144    144     144     144      2
# 4  2024-04-11       23        143    144     143     143     17
# 5  2024-04-12       24        144    144     144     144     23
# 6  2024-04-13       24        143    144     144     144     12
# 7  2024-04-14       23        144    144     144     144     24
# 8  2024-04-15       12         75     74      75      75      5

# %%
nrb = cfg["nrb-brewer"]
# n = hk.organize_files(nrb)
# print(f"Finished organizing files under '{nrb['root']}'. {n} files moved.")

days = 7
stats = fc.get_file_coverage(cfg=nrb, days=days)
fc.plot_coverage(stats=stats, days=days)
fc.print_coverage(stats=stats, days=days)
# Out:
#         index  071
# 0    expected    1
# 1  2024-04-08    0
# 2  2024-04-09    0
# 3  2024-04-10    0
# 4  2024-04-11    0
# 5  2024-04-12    0
# 6  2024-04-13    0
# 7  2024-04-14    0
# 8  2024-04-15    0

# %%
nrb = cfg["nrb-dobson"]
n = hk.organize_files(nrb, branch="uploads")
print(f"Finished organizing files under '{nrb['root']}'. {n} files moved.")

days = 60
stats = fc.get_file_coverage(cfg=nrb, days=days)
fc.plot_coverage(stats=stats, days=days)
fc.print_coverage(stats=stats, days=days)
# Out:
# Finished organizing files under '/product_data/data/pay/Kenya'. 0 files moved.
#          index  prod
# 0     expected   260
# 1   2024-02-15     1
# 2   2024-02-16     0
# 3   2024-02-17     0
# 4   2024-02-18     0
# ..         ...   ...
# 57  2024-04-11     1
# 58  2024-04-12     1
# 59  2024-04-13     0
# 60  2024-04-14     0
# 61  2024-04-15     0
#
# [62 rows x 2 columns]

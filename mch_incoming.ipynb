# %%
# Run this script at MeteoSwiss to assess the files available on our netshares.
# Author: joerg.klausen@meteoswiss.ch
import yaml
import housekeeping.organize_files as hk
import monitoring.file_coverage as fc

with open("mch-config.yml", "r") as fh:
    cfg = yaml.safe_load(fh)
    fh.close()

# %%
# organize newly incoming files on disk
mkn = cfg["mkn"]
n = hk.organize_files(mkn, branch="incoming", verbosity=1)
# m = n = hk.organize_files(mkn, branch="archive", verbosity=1)
# Out:
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/aerosol'. 1 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/ae33/data'. 4 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/meteo'. 3 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/tei49c'. 4 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/tei49i'. 4 files moved.
# Finished organizing files under '/product_data/data/pay/Kenya/MKN/incoming/g2401'. 2 files moved.

# %%
# show and plot file statistics
days = 7
stats = fc.get_file_coverage(cfg=mkn, days=days)
display(df:=fc.print_coverage(stats=stats, days=days))
fc.plot_coverage(stats=stats, days=days)
# Out:
#         index  aerosol  ae33/data  meteo  tei49c  tei49i  g2401
# 0    expected       24        144    144     144     144     24
# 1  2024-02-07        0          0      0       0       0      0
# 2  2024-02-08        0          0      0       0       0      0
# 3  2024-02-09       15        101    101     101     101     17
# 4  2024-02-10       23        138    138     138     138     22
# 5  2024-02-11       23        144    144     144     144     24
# 6  2024-02-12       23        143    144     144     144     19
# 7  2024-02-13       23        144    144     144     144      8
# 8  2024-02-14       15         93     91      93      93      8

# %%
nrb = cfg["nrb-brewer"]
# n = hk.organize_files(nrb)
# print(f"Finished organizing files under '{nrb['root']}'. {n} files moved.")

days = 7
stats = fc.get_file_coverage(cfg=nrb, days=days)
fc.plot_coverage(stats=stats, days=days)
fc.print_coverage(stats=stats, days=days)

# %%
nrb = cfg["nrb-dobson"]
n = hk.organize_files(nrb, branch="uploads")
print(f"Finished organizing files under '{nrb['root']}'. {n} files moved.")

days = 60
stats = fc.get_file_coverage(cfg=nrb, days=days)
fc.plot_coverage(stats=stats, days=days)
fc.print_coverage(stats=stats, days=days)
# Out:
# Finished organizing files under '/product_data/data/pay/Kenya'. 0 files moved.
#          index  prod
# 0     expected   260
# 1   2023-12-16     0
# 2   2023-12-17     0
# 3   2023-12-18     1
# 4   2023-12-19     1
# ..         ...   ...
# 57  2024-02-10     0
# 58  2024-02-11     0
# 59  2024-02-12     0
# 60  2024-02-13     0
# 61  2024-02-14     0
#
# [62 rows x 2 columns]
